# %%
import numpy as np

# %% [markdown]
# Exemples random numbers

# %%
a=np.random.uniform(-1.0,1.0) #numero aleatori entre -1 i 1
print(a)
# Out:
# 0.4558296833991329

# %%
# per generar numeros aleatoris enters
b=np.random.randint(1,6)
print(b)
# Out:
# 1
